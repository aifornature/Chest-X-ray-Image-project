# %%
pwd
# Out:
# '/Users/i/Downloads/cv_project/classification_code'

# %%
import os

# 모델 저장 파일 생성 및 경로 설정
save_path='/Users/i/Downloads/cv_project/classification_code'

## /content/gdrive/MyDrive/YOLO 경로 생성
if not os.path.exists(os.path.join(save_path,'YOLO')):
  os.makedirs(os.path.join(os.path.join(save_path,'YOLO')))
save_path1=f'{save_path}/YOLO'

## /content/gdrive/MyDrive/YOLO/classification 경로 생성
if not os.path.exists(os.path.join(save_path1,'classification9')):
  os.makedirs(os.path.join(os.path.join(save_path1,'classification9')))
save_path2=f'{save_path1}/classification9'

# %cd /Users/i/Downloads/cv_project/classification_code/YOLO/classification9
# !ls

# 모델 다운로드
from ultralytics import YOLO
model=YOLO('./models/yolov8m-cls.pt')
# Out:
# /Users/i/Downloads/cv_project/classification_code/YOLO/classification9
# ...
# 100%|██████████| 32.7M/32.7M [00:02<00:00, 12.3MB/s]

# %%
import torch

print(f"MPS 장치를 지원하도록 build가 되었는가? {torch.backends.mps.is_built()}")
print(f"MPS 장치가 사용 가능한가? {torch.backends.mps.is_available()}") 

device = torch.device("mps" if torch.cuda.is_available() else "cpu")
# Out:
# MPS 장치를 지원하도록 build가 되었는가? True
# MPS 장치가 사용 가능한가? True

# %%
pwd
# Out:
# '/Users/i/Downloads/cv_project/classification_code/YOLO/classification9'

# %%
# train
results = model.train(data="/Users/i/Downloads/cv_project/chest_xray_data_mini3/chest_xray", epochs=100, imgsz=64, project=save_path2)
# Out:
# Ultralytics YOLOv8.2.48 🚀 Python-3.12.4 torch-2.3.1 CPU (Apple M1)
# ...

# %%
pwd
# Out:
# '/Users/i/Downloads/cv_project/classification_code/YOLO/classification9'

# %% [markdown]
# # valid

# %%
model = YOLO("./train/weights/best.pt")  # load a custom model
metrics = model.val(data="/Users/i/Downloads/cv_project/chest_xray_data_mini3/chest_xray",
                    project=save_path2)  
metrics.top5  # top5 accuracy
# Out:
# Ultralytics YOLOv8.2.48 🚀 Python-3.12.4 torch-2.3.1 CPU (Apple M1)
# YOLOv8m-cls summary (fused): 103 layers, 15766499 parameters, 0 gradients, 41.6 GFLOPs
# train: /Users/i/Downloads/cv_project/chest_xray_data_mini3/chest_xray/train... found 540 images in 3 classes ✅
# val: /Users/i/Downloads/cv_project/chest_xray_data_mini3/chest_xray/val... found 180 images in 3 classes ✅
# test: /Users/i/Downloads/cv_project/chest_xray_data_mini3/chest_xray/test... found 180 images in 3 classes ✅
# val: Scanning /Users/i/Downloads/cv_project/chest_xray_data_mini3/chest_xray/val... 180 images, 0 corrupt: 100%|██████████| 180/180 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 12/12 [00:11<00:00,  1.06it/s]
#                    all       0.85          1
# Speed: 0.0ms preprocess, 52.1ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /Users/i/Downloads/cv_project/classification_code/YOLO/classification9/val
# 1.0

# %%
metrics.top1  # top1 accuracy
# Out:
# 0.8500000238418579

# %% [markdown]
# # predict

# %%
# !yolo task=classify mode=predict model=./train/weights/best.pt source=/Users/i/Downloads/cv_project/chest_xray_data_mini3/chest_xray/test/PNEUMONIA_BACTERIA/person78_bacteria_378.jpeg project=/Users/i/Downloads/cv_project/classification_code/YOLO/classification9
# Out:
# Ultralytics YOLOv8.2.48 🚀 Python-3.12.4 torch-2.3.1 CPU (Apple M1)
# YOLOv8m-cls summary (fused): 103 layers, 15766499 parameters, 0 gradients, 41.6 GFLOPs
#
# image 1/1 /Users/i/Downloads/cv_project/chest_xray_data_mini3/chest_xray/test/PNEUMONIA_BACTERIA/person78_bacteria_378.jpeg: 64x64 PNEUMONIA_VIRUS 0.84, PNEUMONIA_BACTERIA 0.16, NORMAL 0.00, 7.1ms
# Speed: 2.0ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# Results saved to /Users/i/Downloads/cv_project/classification_code/YOLO/classification9/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import matplotlib.pyplot as plt
import cv2

img=cv2.imread('/Users/i/Downloads/cv_project/classification_code/YOLO/classification9/train/results.png')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 1199.5, 1199.5, -0.5)

# %%
import matplotlib.pyplot as plt
import cv2

img=cv2.imread('/Users/i/Downloads/cv_project/classification_code/YOLO/classification9/train/results.png')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(100,30))
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 1199.5, 1199.5, -0.5)
